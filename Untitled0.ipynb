# %% [markdown]
# <a href="https://colab.research.google.com/github/Vini1905/ENIAC-Est-gio/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()

# %% [markdown]
# # RELATÓRIO- ENIAC ACADEMY
#
# ## 1. CONDUTA PROFISSIONAL
#
# O profissional deve ser claro e respeitoso nas interações:
#
# * Informando aos supervisores sobre qualquer dificuldade de maneira imediata e progredindo com feedbacks.
# * Aderindo às normas da empresa.
# * Protegendo os recursos da empresa e os utilizando para fins de exclusividade do estágio.
# * Deve visar a construção de um ambiente imparcial e notificar, de maneira imediata, em caso de conduta inadequada do supervisor ou da equipe.
#
# ## 2. COMPROMISSO
#
# O estagiário deve estar buscando aprimoramento de suas habilidades e aprendizado contínuo, além de estar participando das atividades propostas pela organização e estar disposto a representar o **ENIAC Academy**, de forma profissional.
#
# ## 3. LIDERANÇA
#
# O objetivo da etapa é de compreendermos o papel da liderança, desenvolvermos *soft skills* e valorizar a hierarquia como pilar para uma relação saudável entre profissionais.
#
# > A liderança não necessariamente é sinônimo de ocupar um cargo de chefia e sim, a capacidade de influenciar pessoas, inspirar e conduzir equipes.
#
# ## 4. SOFT SKILLS
#
# * **Comunicação assertiva:** Falar e ouvir com clareza.
# * **Empatia:** Se colocar no lugar do outro.
# * **Resolução de conflitos:** Intermediar impasses de forma equilibrada.
# * **Colaborar:** Trabalhar com a equipe e incentivar o protagonismo.
# * **Flexibilidade:** Adaptação.
#
# ---
#
# ## 5. EXERCÍCIO
#
# Eu possuo a capacidade de empatia, o que pode me auxiliar a enxergar o grupo como um todo e compreender o seu contexto, trazendo o protagonismo aos indivíduos. A capacidade de Colaboração é algo que possuo, busco sempre ser proativo e interagir com o grupo sobre as demandas necessárias.
#
# **Situação de discordância com um líder:**
# Eu buscaria abordar o problema de forma educada e respeitoso, além de propor uma resolução.
#
# **Desafio:**
# Eu iria abordar o líder respeitosamente e buscaria pedir uma reunião privada com o mesmo, eu iria trazer os dados demonstrando uma solução mais viável e as consequências negativas se fossemos seguir pela outra rota.
#
# ---
#
# ## 6. INTELIGÊNCIA ARTIFICIAL (IA)
#
# IA é o campo da ciência da computação focado na criação de sistemas que executem tarefas que exigiram interação humana, o grande foco é a automação de processos, para gerar valor ao Ecossistema ENIAC.
#
# * **Análise de Dados:** Extração de Insights e informações valiosas através de dados existentes.
# * **Machine Learning:** Treinamento de algoritmos para fazer previsões.
# * **Automação:** Utilização de tecnologia para realizar tarefas repetitivas.
#
# ### Ciclo CRISP-DM
#
# Um projeto de dados deve seguir o ciclo de vida nos passos:
#
# 1. Entendimento do Negócio
# 2. Entendimento de Dados
# 3. Preparação de Dados
# 4. Modelagem
# 5. Avaliação
# 6. Implantação (Deploy)
#
# > **Nota:** O trainee de IA é responsável por apoiar as etapas iniciais e intermediárias do ciclo de vida de um projeto de dados.
#
# ---
#
# ## 7. DESENVOLVIMENTO E FERRAMENTAS
#
# ### Python
#
# Linguagem de programação básica para IA, sendo a nossa principal ferramenta de trabalho: para organizar dados, criar lógica e trazer vida às soluções.
#
# **Estrutura de Dados Essenciais:**
#
# * **Listas:** Coleções ordenadas e mutáveis.
#
# ```python
# projetos = ["Automação", "Chatbot"]
#
# ```
#
# * **Dicionário:** Coleções não ordenadas de pares chave-valor.
#
# ```python
# projeto_chatbot = {
#    "nome": "Chatbot",
#    "status": "Em desenvolvimento"
# }
#
# ```
#
# ### Cap.4 - Manipulação de Dados
#
# Para manipularmos grandes volumes de dados utilizamos a biblioteca **Pandas**. Esta utiliza *DataFrames*, que são como tabelas ou planilhas, que podem carregar, filtrar, agrupar e transformar dados.
#
# ### Cap.5 - Visualização
#
# Gráficos de Dashboards são a melhor ferramenta para comunicar insights, nos permitindo identificar tendências e padrões, comunicar resultados complexos, apoiar tomadas de decisões e contar uma história com dados. Para isso utilizamos as bibliotecas **Matplotlib** e **Seaborn**.
#
# ### Cap.6 - Automação e APIs
#
# O **JavaScript** permite automatizar os processos no front-end, criando scripts de automação que agem sobre os dados. Podemos automatizar usando scripts Python ou através de **APIs** (scripts que se conectam a outras ferramentas).
#
# ### Cap.7 - Boas Práticas e Ética
#
# * **Código:** Utilizamos a indentação correta, nomes de variáveis/funções descritivos e comentários explicativos.
# * **Viés:** Devemos estar atentos aos vieses que os modelos de IA podem apresentar (preconceitos).
# * **Transparência:** Entender por que o modelo de IA tomou a decisão.
# * **Privacidade:** Sempre usar os dados de forma anônima.
#
# ---
#
# ## 8. CONTROLE DE VERSÃO
#
# ### Git
#
# Sistema de controle de versões do projeto. É útil pois permite que voltemos às versões anteriores da análise, evita conflitos de códigos e dá mais organização ao projeto.
#
# * `git init`: Inicia o repositório git na pasta.
# * `git add`: Adiciona as alterações para serem salvas.
# * `git commit -m "mensagem"`: Salva as alterações com uma mensagem descritiva.
#
# ### GitHub
#
# Armazena os repositórios GIT na nuvem. Onde podemos hospedar projetos, compartilhar portfólios e trabalhar de forma colaborativa.
#
# ---
